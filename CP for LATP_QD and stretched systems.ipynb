# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## CP for LATP_QD and stretched systems.xlsx visualization

# %%
# Load the Excel file
file_path = 'CP for LATP_QD and stretched systems.xlsx'
xls = pd.ExcelFile(file_path)

# %% [markdown]
# ### first_sheet (LATP_CNF_QD)

# %%
# Load the first sheet into a DataFrame
first_sheet_df = xls.parse(xls.sheet_names[0], header=1)

# Display the first few rows of the DataFrame
print(first_sheet_df.head(2))
first_sheet_df.columns
# Out:
#     time, h  LATP_QD3  LATP_CNF20  LATP_CNF20_QD3
# 0  1.099302  0.013522    0.035028        0.043335
# 1  1.107636  0.161992    0.073059        0.087239
# Index(['time, h', 'LATP_QD3', 'LATP_CNF20', 'LATP_CNF20_QD3'], dtype='object')

# %%
first_sheet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12322 entries, 0 to 12321
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   time, h         12322 non-null  float64
#  1   LATP_QD3        12322 non-null  float64
#  2   LATP_CNF20      12322 non-null  float64
#  3   LATP_CNF20_QD3  12322 non-null  float64
# dtypes: float64(4)
# memory usage: 385.2 KB

# %%
# Function to calculate similarity percentage
def calculate_similarity(col1, col2, df=first_sheet_df):
    comparison = df[col1] == df[col2]
    matching_count = comparison.sum()
    total_count = comparison.count()
    proportion_identical = matching_count / total_count
    return proportion_identical

# %%
# Define the time columns
columns_to_plot = ['LATP_QD3', 'LATP_CNF20', 'LATP_CNF20_QD3']

# Compare each pair of time columns and print the results
similarity_results = {}
for i in range(len(columns_to_plot)):
    for j in range(i + 1, len(columns_to_plot)):
        col1 = columns_to_plot[i]
        col2 = columns_to_plot[j]
        similarity = calculate_similarity(col1, col2)
        similarity_results[(col1, col2)] = similarity
        print(f"Similarity between {col1} and {col2}: {similarity:.2%}")
# Out:
# Similarity between LATP_QD3 and LATP_CNF20: 0.00%
# Similarity between LATP_QD3 and LATP_CNF20_QD3: 0.00%
# Similarity between LATP_CNF20 and LATP_CNF20_QD3: 0.00%

# %%
# Define time column and columns to plot
time_column = ['time, h']
columns_to_plot = ['LATP_QD3', 'LATP_CNF20', 'LATP_CNF20_QD3']

# Plot each relevant column against 'time/hours'
for col in columns_to_plot:
    for time_col in time_column:
        plt.figure(figsize=(10, 5))
        plt.plot(first_sheet_df[time_col], first_sheet_df[col], label=col)
        plt.xlabel(time_col)
        plt.ylabel(col)
        plt.title(f'{col} vs {time_col}')
        plt.legend()
        plt.grid(True)
        plt.show()

# %% [markdown]
# ### second_sheet (LATP_CNF_QD_OPTIMIZED)

# %%
# Load the first sheet into a DataFrame
second_sheet_df = xls.parse(xls.sheet_names[1], header=1)

# Display the first few rows of the DataFrame
print(second_sheet_df.head(2))

second_sheet_df.columns
# Out:
#      time/h      CNF0     CNF10     CNF20
# 0  0.000000  1.205604  0.020093  0.009592
# 1  0.020367  4.707686  0.078461  0.082238
# Index(['time/h', 'CNF0', 'CNF10', 'CNF20'], dtype='object')

# %%
second_sheet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15844 entries, 0 to 15843
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time/h  15844 non-null  float64
#  1   CNF0    15844 non-null  float64
#  2   CNF10   15844 non-null  float64
#  3   CNF20   15844 non-null  float64
# dtypes: float64(4)
# memory usage: 495.3 KB

# %%
# Define the time columns
columns_to_plot = ['CNF0', 'CNF10', 'CNF20']

# Compare each pair of time columns and print the results
similarity_results = {}
for i in range(len(columns_to_plot)):
    for j in range(i + 1, len(columns_to_plot)):
        col1 = columns_to_plot[i]
        col2 = columns_to_plot[j]
        similarity = calculate_similarity(col1, col2,second_sheet_df)
        similarity_results[(col1, col2)] = similarity
        print(f"Similarity between {col1} and {col2}: {similarity:.2%}")
# Out:
# Similarity between CNF0 and CNF10: 0.00%
# Similarity between CNF0 and CNF20: 0.00%
# Similarity between CNF10 and CNF20: 0.00%

# %%
# Define time column and columns to plot
time_column = ['time/h']

# Plot each relevant column against 'time/hours'
for col in columns_to_plot:
    for time_col in time_column:
        plt.figure(figsize=(10, 5))
        plt.plot(second_sheet_df[time_col], second_sheet_df[col], label=col)
        plt.xlabel(time_col)
        plt.ylabel(col)
        plt.title(f'{col} vs {time_col}')
        plt.legend()
        plt.grid(True)
        plt.show()

# %% [markdown]
# ### Third_sheet (inset PEO)

# %%
# Load the first sheet into a DataFrame
third_sheet = xls.parse(xls.sheet_names[2], header=1)

# Display the first few rows of the DataFrame
print(third_sheet.head(2))

third_sheet.columns
# Out:
#     time, h     CNF20  stretched CNF20  stretched CNF10
# 0  0.000000  0.000000         0.000000         0.000000
# 1  0.549651  0.173338         0.086669         0.065002
# Index(['time, h', 'CNF20', 'stretched CNF20', 'stretched CNF10'], dtype='object')

# %%
third_sheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12323 entries, 0 to 12322
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time, h          12323 non-null  float64
#  1   CNF20            12323 non-null  float64
#  2   stretched CNF20  12323 non-null  float64
#  3   stretched CNF10  10743 non-null  float64
# dtypes: float64(4)
# memory usage: 385.2 KB

# %%
# Define the time columns
columns_to_plot = ['CNF20', 'stretched CNF20', 'stretched CNF10']

# Compare each pair of time columns and print the results
similarity_results = {}
for i in range(len(columns_to_plot)):
    for j in range(i + 1, len(columns_to_plot)):
        col1 = columns_to_plot[i]
        col2 = columns_to_plot[j]
        similarity = calculate_similarity(col1, col2,third_sheet)
        similarity_results[(col1, col2)] = similarity
        print(f"Similarity between {col1} and {col2}: {similarity:.2%}")
# Out:
# Similarity between CNF20 and stretched CNF20: 0.01%
# Similarity between CNF20 and stretched CNF10: 0.01%
# Similarity between stretched CNF20 and stretched CNF10: 0.01%

# %%
# Define time column and columns to plot
time_column = ['time, h']

# Plot each relevant column against 'time/hours'
for col in columns_to_plot:
    for time_col in time_column:
        plt.figure(figsize=(10, 5))
        plt.plot(third_sheet[time_col], third_sheet[col], label=col)
        plt.xlabel(time_col)
        plt.ylabel(col)
        plt.title(f'{col} vs {time_col}')
        plt.legend()
        plt.grid(True)
        plt.show()
